# %%
import yfinance as yf

# %%
train = yf.download('^GSPC', start= '2018-01-01', end='2022-12-31')
test = yf.download('^GSPC', start= '2023-01-01', end='2024-03-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# plot the data
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.legend()
plt.title('S&P 500 Close')
plt.show()

# %%
aapl = yf.download('AAPL', start= '2018-01-01', end='2022-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
aapl
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   40.615887
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   40.608810
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   40.797443
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.261940
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.108681
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  130.782562
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  128.967529
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.010117
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.550964
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  128.868332
#
#                Volume
# Date
# 2018-01-02  102223600
# 2018-01-03  118071600
# 2018-01-04   89738400
# ...
